# %% [markdown]
# # NeuroBioSense Multimodal Emotion Recognition (T4 GPU Trainer)This notebook is configured to run the stage 3 training suite utilizing Google Colab's T4 GPU for massively accelerated training and higher batch sizes.

# %% [markdown]
# ## 1. Mount Google Drive
# Run this cell to connect your Google Drive so the notebook can access the `NeuroBioSense_DL_Proj` folder containing the code and dataset.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 2. Navigate to Project Directory
# Change directories to where you uploaded `NeuroBioSense_DL_Proj`.

# %%
import os

# CHANGE THIS PATH to wherever you uploaded the folder in your Drive!
# Example: '/content/drive/MyDrive/NeuroBioSense_DL_Proj'
PROJECT_DIR = '/content/drive/MyDrive/NeuroBioSense_DL_Proj'

os.chdir(PROJECT_DIR)
print("Current Directory:", os.getcwd())

# %% [markdown]
# ## 3. Install Dependencies
# Install `facenet-pytorch`. (Colab already has `torch`, `torchvision`, `numpy`, and `pandas` pre-installed).

# %%
# !pip install facenet-pytorch

# %% [markdown]
# ## 4. Launch High-Accuracy Multimodal Training
# Because the T4 has 16GB of VRAM, we can increase the batch size safely to `16` or `32` to train significantly faster.

# %%
# !python -m emotion_recognition.scripts.train_multimodal --epochs 20 --unfreeze-backbone --batch-size 32
